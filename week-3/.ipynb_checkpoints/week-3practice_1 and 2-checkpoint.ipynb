# %%
import tkinter as tk

# handling button click event
def button_click():
    #print("Button clicked!")

    # show an information message box
    msgbox.showinfo("info", "Welcome to COS 102 GUI App!\n")

    # Ask for user confirmation
    result = msgbox.askyesno("Confirmation", "Do you want to continue?")

# Create the main window
root = tk.Tk()
root.title("Home page")
root.geometry("300x100")

# Add a label widget
label = tk.Label(root, text="Welcome \n")
label.pack()

# Add a button widget
button = tk.Button(root, text="Confirm!", command=button_click)
button.pack()

# Styling the button widget
button.config(fg="white", bg="blue")

# Start the event looop
root.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def welcomeMessage(username):
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Admin Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=(f"Welcome back, {username}\n!!"))
    label_1.pack()
    label_2 = tk.Label(window, text="This is Python GUI with Tkinter")
    label_2.pack()

    
    # Run the Tkinter event loop
    root.mainloop()

def submit():
    username = username_entry.get()
    password = password_entry.get()

    if username == "Lugard" and password == "COS102":
        welcomeMessage(username)
    else:
        messagebox.showerror("Login", "You no put correct Username abi na Password, one of them sha no correct!!")

# Create main window
root = tk.Tk()
root.title("Login Form")
root.geometry("500x400")


# create the username and entry
username_label = tk.Label(root, text="Username:")
username_label.pack()
username_entry = tk.Entry(root)
username_entry.pack()

# Create the password label and entry
password_label = tk.Label(root, text="Password")
password_label.pack()
password_entry = tk.Entry(root, show="*")
password_entry.pack()

# Create the submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
